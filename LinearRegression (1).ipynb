# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
veriler=pd.read_csv("satislar.csv")

# %%
aylar=veriler[["Aylar"]]

# %%
satislar=veriler[["Satislar"]]

# %%
satislar2=veriler.iloc[:,:1].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(aylar,satislar,test_size=0.33,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
x_train=sc.fit_transform(x_train)

# %%
x_test=sc.fit_transform(x_test)
y_train=sc.fit_transform(y_train)
y_test=sc.fit_transform(y_test)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([[-1.33324088],
#        [ 1.05398097],
#        [-0.65761206],
#        [-0.70265398],
#        [ 0.82877136],
#        [ 0.60356175],
#        [ 0.82877136],
#        [-0.70265398],
#        [-0.29727668],
#        [ 0.37835214]])

# %%
x_train=pd.DataFrame(data=x_train)

# %%
y_train=pd.DataFrame(data=y_train)

# %%
x_train=x_train.sort_index()
y_train=y_train.sort_index()

# %%
plt.plot(x_train,y_train,data=)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-4b8b69c6cfd6> in <module>
# ----> 1 plt.plot(x_train,y_train)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
# -> 2842         **({"data": data} if data is not None else {}), **kwargs)
#    2843
#    2844
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
#    1742         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1743         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1744         for line in lines:
#    1745             self.add_line(line)
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/axes/_base.py in __call__(self, data, *args, **kwargs)
#     271                 this += args[0],
#     272                 args = args[1:]
# --> 273             yield from self._plot_args(this, kwargs)
#     274
#     275     def get_next_color(self):
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     386
#     387         if len(tup) == 2:
# --> 388             x = _check_1d(tup[0])
#     389             y = _check_1d(tup[-1])
#     390         else:
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/matplotlib/cbook/__init__.py in _check_1d(x)
#    1316                     message='Support for multi-dimensional indexing')
#    1317
# -> 1318                 ndim = x[:, None].ndim
#    1319                 # we have definitely hit a pandas index or series object
#    1320                 # cast to a numpy array.
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2904             if self.columns.nlevels > 1:
#    2905                 return self._getitem_multilevel(key)
# -> 2906             indexer = self.columns.get_loc(key)
#    2907             if is_integer(indexer):
#    2908                 indexer = [indexer]
#
# /srv/conda/envs/notebook/lib/python3.6/site-packages/pandas/core/indexes/range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
#     359         return super().get_loc(key, method=method, tolerance=tolerance)
#     360
#
# KeyError: (slice(None, None, None), None)
